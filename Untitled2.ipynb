# %%
for i in range(1, 26):
    print(f"""
        <tr>
      <th scope="row">{i}</th>
      <td><input type="text" name="date{i}" id="date{i}" placeholder="" value=""><br></td>
      <td><input type="text" name="purchase{i}" id="purchase{i}" placeholder="" value=""><br></td>
      <td><input type="text" name="cost{i}" id="cost{i}" placeholder="" value=""><br></td>
      <td><select name="category{i}" id="category{i}">
        zzz if data['category{i}'] == 'need' yyy
          <option value="need" selected>Need</option>
        zzz else yyy
          <option value="need">Need</option>
        zzz endif yyy
        zzz if data['category{i}'] == 'need' yyy
          <option value="want">Want</option>
        zzz else yyy
          <option value="want" selected>Want</option>
        zzz endif yyy
          </select>
      </td>
    </tr>
    """)
# Out:
#         <tr>
#       <th scope="row">1</th>
#       <td><input type="text" name="date1" id="date1" placeholder="" value=""><br></td>
#       <td><input type="text" name="purchase1" id="purchase1" placeholder="" value=""><br></td>
#       <td><input type="text" name="cost1" id="cost1" placeholder="" value=""><br></td>
#       <td><select name="category1" id="category1">
#         zzz if data['category1'] == 'need' yyy
#           <option value="need" selected>Need</option>
#         zzz else yyy
#           <option value="need">Need</option>
#         zzz endif yyy
#         zzz if data['category1'] == 'need' yyy
#           <option value="want">Want</option>
#         zzz else yyy
#           <option value="want" selected>Want</option>
#         zzz endif yyy
#           </select>
#       </td>
#     </tr>
#
#
#         <tr>
#       <th scope="row">2</th>
#       <td><input type="text" name="date2" id="date2" placeholder="" value=""><br></td>
# ...

# %%
import pandas as pd
df = pd.DataFrame({'date': ['2021-01-01', '2021-02-05']})
df
# Out:
#          date
# 0  2021-01-01
# 1  2021-02-05

# %%
df['date'].apply(lambda x: x[8:10])
# Out:
# 0    01
# 1    05
# Name: date, dtype: object

# %%
from datetime import datetime
str(datetime.now().month).zfill(2)
# Out:
# '03'

# %%
str(datetime.now().year)
# Out:
# '2021'

# %%
for index, row in df.iterrows():
    print(index)
# Out:
# 0
# 1

# %%
'12'.zfill(2)
# Out:
# '12'

# %%
from glob import glob

# %%
files = glob("/Users/petermyers/Desktop/high_quality_programs/24_nonessential_budget_tracker/app/static/*")
files = [x for x in files if ".png" in x]

for file in files:
    print(int(file[:-4].split("/static/plot")[1]))
# Out:
# 1
